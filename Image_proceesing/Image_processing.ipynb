# %%
from PIL import Image 
import numpy as np
import matplotlib.pyplot as plt

# %%
img = Image.open("im2.png")

# %%
arr =np.array(img)

# %%
arr.shape
# Out:
# (225, 225)

# %%
img
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=P size=225x225 at 0x27F8EF60E48>

# %%
red= arr[:225,:225]

# %%
plt.imshow(red)

# %%
slice2= arr[:120,:120]

# %%
plt.imshow(slice2)

# %%
work = arr.copy()

# %%
work[:, [1,2]].shape
# Out:
# (225, 2)

# %%
plt.imshow(work)

# %%
img2 = Image.open("thor.jpg")
arr4 =np.array(img2)
arr4.shape
# Out:
# (246, 220, 3)

# %%
red= arr4[:5,:5]

# %%
img2
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=220x246 at 0x27F8ED61408>

# %%
plt.imshow(red)

# %%
w = arr4.copy()

# %%
w[:,:,[1,2]] = 0

# %%
plt.imshow(w)

# %%
w[:,:,[1,2]] = 255
plt.imshow(w)

# %%
w[:,:,[1,2]] = 2000
plt.imshow(w)

# %%
grey = arr4.mean(axis=2)

# %%
plt.imshow(grey,cmap=None)
